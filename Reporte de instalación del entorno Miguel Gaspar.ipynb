# %% [markdown]
# # Instalación del entorno de desarrollo
# ### Por Miguel alejandro Gaspar Vizcaíno
# ## Ingenieria en Computación Inteligente
# ### Activamos dentro de las caracteristicas de windows "subsistema de linux para windows"
#
# ![image-2.png](attachment:image-2.png)
#
# ### Dentro de nuestra terminal ingresamos el comando "wsl --list --online"
# ### Para ver todas las distribuciones de linux para windows
# ### Usaremos Ubuntu
#
# ![image-5.png](attachment:image-5.png)
#
# ### Listo, ya tenemos terminal de linux
#
# ![image.png](attachment:image.png)
#
#  ### Es hora de crear nuestro workspace con el comando "mkdir"
#
#  ![image-4.png](attachment:image-4.png)
#
# ### Dentro de este entorno
# ### Podremos crear directorios donde almacenaremos nuestros documentos, con elmismo comando de "mkdir"
# ### Una vez creado podremos acceder a vscode con el comando "code ."
# ![image-3.png](attachment:image-3.png)
# ### Listo, hemos entrado a visual studio code desde linux
